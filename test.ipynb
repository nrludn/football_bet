# %%
from datafc.sofascore import (
    match_data,
    match_odds_data,
    match_stats_data,
    momentum_data,
    lineups_data,
    coordinates_data,
    substitutions_data,
    goal_networks_data,
    shots_data,
    standings_data
)

standings_df = standings_data(
    tournament_id=52,
    season_id=63814
)
standings_df=standings_df[standings_df['category']=='Total']
standings_df=standings_df[['team_name','matches','wins','draws','losses','scores_for','scores_against','points']]
standings_df.columns=['Takım','O','G','B','M','A','Y','Puan']
standings_df = standings_df.reset_index().rename(columns={'index': 'Sıralama'})
standings_df
# Out:
#     Sıralama            Takım   O   G   B   M   A   Y  Puan
# 0          0      Galatasaray  25  20   5   0  62  26    65
# 1          1       Fenerbahçe  25  19   4   2  63  23    61
# 2          2       Samsunspor  25  14   5   6  41  28    47
# 3          3         Beşiktaş  24  12   8   4  38  23    44
# 4          4         Eyüpspor  25  11   7   7  37  27    40
# 5          5          Göztepe  24  10   6   8  42  30    36
# 6          6    Başakşehir FK  24  10   6   8  40  31    36
# 7          7  Çaykur Rizespor  25  10   3  12  33  42    33
# 8          8      Trabzonspor  24   8   8   8  39  29    32
# 9          9     Gaziantep FK  24   9   5  10  33  34    32
# 10        10        Kasımpaşa  25   7  11   7  45  50    32
# 11        11       Alanyaspor  25   8   7  10  29  36    31
# 12        12      Antalyaspor  25   8   6  11  28  46    30
# 13        13        Konyaspor  25   7   7  11  31  38    28
# 14        14        Bodrum FK  25   6   6  13  17  29    24
# 15        15        Sivasspor  25   6   6  13  28  41    24
# 16        16      Kayserispor  24   5   9  10  24  44    24
# 17        17        Hatayspor  24   2   7  15  24  43    13
# 18        18  Adana Demirspor  25   2   4  19  23  57    -2

# %%
standings_df = standings_df.reset_index().rename(columns={'index': 'Sıralama'})

standings_df
# Out:
#     Sıralama  Sıralama            Takım   O   G   B   M   A   Y  Puan
# 0          0         0      Galatasaray  25  20   5   0  62  26    65
# 1          1         1       Fenerbahçe  25  19   4   2  63  23    61
# 2          2         2       Samsunspor  25  14   5   6  41  28    47
# 3          3         3         Beşiktaş  24  12   8   4  38  23    44
# 4          4         4         Eyüpspor  25  11   7   7  37  27    40
# 5          5         5          Göztepe  24  10   6   8  42  30    36
# 6          6         6    Başakşehir FK  24  10   6   8  40  31    36
# 7          7         7  Çaykur Rizespor  25  10   3  12  33  42    33
# 8          8         8      Trabzonspor  24   8   8   8  39  29    32
# 9          9         9     Gaziantep FK  24   9   5  10  33  34    32
# 10        10        10        Kasımpaşa  25   7  11   7  45  50    32
# 11        11        11       Alanyaspor  25   8   7  10  29  36    31
# 12        12        12      Antalyaspor  25   8   6  11  28  46    30
# 13        13        13        Konyaspor  25   7   7  11  31  38    28
# 14        14        14        Bodrum FK  25   6   6  13  17  29    24
# 15        15        15        Sivasspor  25   6   6  13  28  41    24
# 16        16        16      Kayserispor  24   5   9  10  24  44    24
# 17        17        17        Hatayspor  24   2   7  15  24  43    13
# 18        18        18  Adana Demirspor  25   2   4  19  23  57    -2

# %%
from datafc.sofascore import (
    match_data,
    match_odds_data,
    match_stats_data,
    momentum_data,
    lineups_data,
    coordinates_data,
    substitutions_data,
    goal_networks_data,
    shots_data,
    standings_data
)
import pandas as pd
import json
import numpy as np
from tqdm import tqdm  # For progress bar

# Create an empty list to store dataframes for each week
all_matches = []

# Fetch data for weeks 1 through 25
for week in range(1, 30):
    week_df = match_data(
        tournament_id=8,
        season_id=61643,
        week_number=week
    )
    all_matches.append(week_df)
    print(f"Fetched data for week {week}")

# Combine all dataframes into a single dataframe
match_df = pd.concat(all_matches, ignore_index=True)
print(f"Total matches fetched: {len(match_df)}")
data=match_df.copy()

data=data[['country','tournament','season','week','home_team','away_team','home_score_display','away_score_display']]
data.rename(columns={
    'home_score_display': 'home_score',
    'away_score_display': 'away_score'
}, inplace=True)

data=data[data['home_score']!=""]
json_data = data.to_json(orient="records", indent=2)

# JSON verisini dosyaya kaydediyoruz.
json_file_path = "match_results_spa.json"
with open(json_file_path, "w") as json_file:
    json_file.write(json_data)
# Out:
# Fetched data for week 1
# Fetched data for week 2
# Fetched data for week 3
# Fetched data for week 4
# Fetched data for week 5
# Fetched data for week 6
# Fetched data for week 7
# Fetched data for week 8
# Fetched data for week 9
# Fetched data for week 10
# Fetched data for week 11
# Fetched data for week 12
# Fetched data for week 13
# Fetched data for week 14
# Fetched data for week 15
# Fetched data for week 16
# Fetched data for week 17
# Fetched data for week 18
# Fetched data for week 19
# Fetched data for week 20
# Fetched data for week 21
# Fetched data for week 22
# Fetched data for week 23
# Fetched data for week 24
# Fetched data for week 25
# Fetched data for week 26
# Fetched data for week 27
# Fetched data for week 28
# Fetched data for week 29
# Total matches fetched: 293
